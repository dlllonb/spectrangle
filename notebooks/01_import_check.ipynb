# %%
import sys
import os

# Make extractor importable from notebooks/
sys.path.insert(0, os.path.abspath('..'))

import extractor

print(f"extractor {extractor.__version__} imported OK")
print(extractor.__description__)
